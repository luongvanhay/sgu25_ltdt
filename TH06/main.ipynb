# %% [markdown]
# # Bài 1: Đường đi giữa các hình tròn

# %%
# !g++ bai1.cpp -o bai1
# !bai1 < text.inp
# Out:
# 1
# 1 3
# 3 0
# 4 1

# %% [markdown]
# input: 4 1 4
#        0 0 5
#        0 20 5
#        0 30 5
#        0 100 10
