# %% [markdown]
# # Bài 2: Đường đi trên bảng

# %% [markdown]
# ## input:
# 3 4 1 1 3 4
# 1 2 3 4
# 0 3 0 2
# 1 2 3 4

# %%
# !g++ bai2.cpp -o bai2
# !bai2 < text.inp
# Out:
# 1
# 7
# 1 1
# 1 2
# 2 2
# 3 2
# 3 3
# 3 4
